# %% [markdown]
# <a href="https://colab.research.google.com/github/darshank26/Linear_Algebra_for_ML/blob/main/14_linear_substitution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Solving linear substitution
#
# y = 3x
#
# -5x + 2y = 2 -> 2y = 2 + 5x -> y = 1 + 5x / 2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,80,2000)

# %%
y1 = 3*x

y2 = 1 + (5 * x ) / 2

# %%
fig , ax = plt.subplots()
plt.title('Linear Substitution ')
plt.xlabel('X')
plt.ylabel('Y')
ax.set_xlim([0,3])
ax.set_ylim([0,8])
ax.plot(t,y1,c='green')
ax.plot(t,y2,c='red')
plt.axvline(x=2,color='black', linestyle = '--')
plt.axhline(y=6,color='black', linestyle = '--')

# %% [markdown]
# y = -5 + 2 * x /  3
#
# y = ( 7 - 2* x ) / 5

# %%
x = np.linspace(0,80,2000)

# %%
y1 = -5 + 2 * x /  3

y2 = ( 7 - 2* x ) / 5

# %%
fig , ax = plt.subplots()
plt.title('Linear Substitution ')
plt.axvline(x = 0, color = 'lightgray')
plt.axhline(y = 0, color = 'lightgray')

plt.xlabel('X')
plt.ylabel('Y')
ax.set_xlim([-2,10])
ax.set_ylim([-6,4])
ax.plot(t,y1,c='green')
ax.plot(t,y2,c='red')
plt.axvline(x=6,color='black', linestyle = '--')
plt.axhline(y=-1,color='black', linestyle = '--')
