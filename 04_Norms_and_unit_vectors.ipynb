# %% [markdown]
# <a href="https://colab.research.google.com/github/darshank26/Linear_Algebra_for_ML/blob/main/04_Norms_and_unit_vectors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #L<sup>2 </sup> Norms or Frobenius Norms

# %% [markdown]
# ![vector-norms-12.png](data:image/png;base64,...)

# %%
import numpy as np

# %%
x = np.array([20,10,30])

# %%
(20**2 + 10**2 + 30**2) ** ( 1/2)
# Out:
# 37.416573867739416

# %%
np.linalg.norm(x)
# Out:
# 37.416573867739416

# %% [markdown]
# #L<sup>1 </sup> Norms

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %%
x
# Out:
# array([20, 10, 30])

# %%
np.abs(20) + np.abs(10) + np.abs(30)
# Out:
# 60

# %% [markdown]
# #Squared L<sup>2 </sup> Norms

# %% [markdown]
# ![Screenshot 2023-10-01 at 1.10.29 AM.png](data:image/png;base64,...)

# %%
x
# Out:
# array([20, 10, 30])

# %%
(20**2 + 10**2 + 30**2)
# Out:
# 1400

# %% [markdown]
# #Max Norms

# %% [markdown]
# ![download (1).png](data:image/png;base64,...)

# %%
x
# Out:
# array([20, 10, 30])

# %%
np.max([np.abs(20), np.abs(10), np.abs(30)])
# Out:
# 30

# %% [markdown]
# #Generalised  Norms Formula for p > 0

# %% [markdown]
# ![vector-norms-15.png](data:image/png;base64,...)
